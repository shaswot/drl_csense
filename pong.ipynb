# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#id2

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

# %%
# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=4, seed=0)
# Frame-stacking with 4 frames
vec_env = VecFrameStack(vec_env, n_stack=4)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
model = A2C("CnnPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25_000)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 100      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.949   |
# |    explained_variance | -0.0231  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0823   |
# |    value_loss         | 0.00655  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.65e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 200      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.69    |
# |    explained_variance | -130     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0926   |
# |    value_loss         | 0.0378   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.65e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 300      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | 0.014    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.149   |
# |    value_loss         | 0.0873   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.47e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 400      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | 0.0253   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.235   |
# |    value_loss         | 0.128    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.39e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 500      |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | 0.0635   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0772  |
# |    value_loss         | 0.0848   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.33e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 389      |
# |    iterations         | 600      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.00389  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0783  |
# |    value_loss         | 0.0465   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.39e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 394      |
# |    iterations         | 700      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.0889   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0704  |
# |    value_loss         | 0.0443   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.39e+03 |
# |    ep_rew_mean        | -20.8    |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 800      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | -0.0804  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0591   |
# |    value_loss         | 0.00141  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.46e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 403      |
# |    iterations         | 900      |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.72    |
# |    explained_variance | -0.128   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0279  |
# |    value_loss         | 0.0613   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.42e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 1000     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.218   |
# |    explained_variance | 0.514    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.033    |
# |    value_loss         | 0.0806   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.4e+03  |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 408      |
# |    iterations         | 1100     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.374   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0678   |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.36e+03 |
# |    ep_rew_mean        | -20.7    |
# | time/                 |          |
# |    fps                | 409      |
# |    iterations         | 1200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.00971  |
# |    value_loss         | 0.000609 |
# ------------------------------------

# %%
model.save("a2c_pong")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.save("a2c_pong")
#
# NameError: name 'model' is not defined

# %%
model = A2C.load("a2c_pong", verbose=1)

# %%
# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=1, seed=0)
# Frame-stacking with 4 frames
vec_env = VecFrameStack(vec_env, n_stack=4)

# %%
obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, rewards, dones, info = vec_env.step(action)
    # vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 while True:
#       3     action, _states = model.predict(obs, deterministic=False)
# ----> 4     obs, rewards, dones, info = vec_env.step(action)
#       5     # vec_env.render("human")
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:188, in VecEnv.step(self, actions)
#     181 """
#     182 Step the environments with the given action
#     183
#     184 :param actions: the action
#     185 :return: observation, reward, done, information
#     186 """
#     187 self.step_async(actions)
# --> 188 return self.step_wait()
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/vec_frame_stack.py:33, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 33     observations, rewards, dones, infos = self.venv.step_wait()
#      34     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      35     return observations, rewards, dones, infos
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:408, in Wrapper.step(self, action)
#     404 def step(
#     405     self, action: WrapperActType
#     406 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     407     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 408     return self.env.step(action)
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:502, in RewardWrapper.step(self, action)
#     498 def step(
#     499     self, action: ActType
#     500 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     501     """Modifies the :attr:`env` :meth:`step` reward using :meth:`self.reward`."""
# --> 502     observation, reward, terminated, truncated, info = self.env.step(action)
#     503     return observation, self.reward(reward), terminated, truncated, info
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:469, in ObservationWrapper.step(self, action)
#     465 def step(
#     466     self, action: ActType
#     467 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     468     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 469     observation, reward, terminated, truncated, info = self.env.step(action)
#     470     return self.observation(observation), reward, terminated, truncated, info
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:408, in Wrapper.step(self, action)
#     404 def step(
#     405     self, action: WrapperActType
#     406 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     407     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 408     return self.env.step(action)
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/atari_wrappers.py:112, in EpisodicLifeEnv.step(self, action)
#     111 def step(self, action: int) -> AtariStepReturn:
# --> 112     obs, reward, terminated, truncated, info = self.env.step(action)
#     113     self.was_real_done = terminated or truncated
#     114     # check current lives, make loss of life terminal,
#     115     # then update lives to handle bonus lives
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/atari_wrappers.py:178, in MaxAndSkipEnv.step(self, action)
#     176 terminated = truncated = False
#     177 for i in range(self._skip):
# --> 178     obs, reward, terminated, truncated, info = self.env.step(action)
#     179     done = terminated or truncated
#     180     if i == self._skip - 2:
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:408, in Wrapper.step(self, action)
#     404 def step(
#     405     self, action: WrapperActType
#     406 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     407     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 408     return self.env.step(action)
#
# File /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File /usr/local/lib/python3.10/dist-packages/shimmy/atari_env.py:294, in AtariEnv.step(self, action_ind)
#     292 reward = 0.0
#     293 for _ in range(frameskip):
# --> 294     reward += self.ale.act(action)
#     295 is_terminal = self.ale.game_over(with_truncation=False)
#     296 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
